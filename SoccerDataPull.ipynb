# %%
import soccerdata as sd
# Out:
# [11/04/22 10:15:30] INFO     No custom team name replacements found. You can configure these in       ]8;id=823368;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=352316;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py#85\85]8;;\
#                              /Users/animeshsengupta/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=443123;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=762313;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py#155\155]8;;\
#                              /Users/animeshsengupta/soccerdata/config/league_dict.json.

# %%
five38 = sd.FiveThirtyEight('ENG-Premier League', '20-21')
# Out:
# [11/04/22 10:33:42] INFO     Saving cached data to                                                    ]8;id=200861;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=129246;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#89\89]8;;\
#                              /Users/animeshsengupta/soccerdata/data/FiveThirtyEight

# %%
games = five38.read_games()

print(games.columns)
# Out:
# Index(['date', 'status', 'leg', 'home_team', 'away_team', 'home_id', 'away_id',
#        'home_code', 'away_code', 'prob_home', 'prob_away', 'prob_tie', 'round',
#        'matchday', 'score_home', 'score_away', 'adj_score_home',
#        'adj_score_away', 'chances_home', 'chances_away', 'moves_home',
#        'moves_away', 'aggregate_winner', 'shootout_winner'],
#       dtype='object')

# %%
games.head(10)
# Out:
#                                                                                               date  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton          2020-09-12 14:00:00+00:00
#                           2020-09-12 Fulham-Arsenal                      2020-09-12 11:30:00+00:00
#                           2020-09-12 Liverpool-Leeds United              2020-09-12 16:30:00+00:00
#                           2020-09-12 West Ham United-Newcastle           2020-09-12 19:00:00+00:00
#                           2020-09-13 Tottenham Hotspur-Everton           2020-09-13 15:30:00+00:00
#                           2020-09-13 West Bromwich Albion-Leicester City 2020-09-13 13:00:00+00:00
#                           2020-09-14 Brighton and Hove Albion-Chelsea    2020-09-14 19:15:00+00:00
#                           2020-09-14 Sheffield United-Wolverhampton      2020-09-14 17:00:00+00:00
# ...

# %%
fbref = sd.FBref(leagues="Big 5 European Leagues Combined",seasons="2021", no_cache=True, no_store=True)
# Out:
# [11/04/22 10:34:29] INFO     Caching is disabled                                                      ]8;id=512315;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=871410;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#87\87]8;;\

# %%
season_stats = fbref.read_team_season_stats(stat_type='shooting')

# %%
season_stats.head(20)
# Out:
#                                           # Pl   90s Standard                  \
#                                                           Gls   Sh  SoT  SoT%
# league             season team
# ENG-Premier League 2021   Arsenal           29  38.0       53  453  140  30.9
#                           Aston Villa       24  38.0       52  514  178  34.6
#                           Brighton          27  38.0       39  478  134  28.0
#                           Burnley           25  38.0       32  381  124  32.5
#                           Chelsea           27  38.0       56  546  193  35.3
#                           Crystal Palace    24  38.0       39  345  127  36.8
#                           Everton           29  38.0       45  395  143  36.2
#                           Fulham            28  38.0       26  436  125  28.7
#                           Leeds United      23  38.0       60  518  193  37.3
#                           Leicester City    27  38.0       64  473  170  35.9
# ...

# %%
possession_stats = fbref.read_team_season_stats(stat_type='goal_shot_creation')
# Out:
# [11/04/22 12:20:51] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=986748;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=638986;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#342\342]8;;\
#                              1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-pack
#                              ages/urllib3/connectionpool.py", line 703, in urlopen
#                                  httplib_response = self._make_request(
#                                File
#                              "/opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-pack
#                              ages/urllib3/connectionpool.py", line 449, in _make_request
#                                  six.raise_from(e, None)
# ...

# %%
possession_stats.head(30)
# Out:
#                                           # Pl   90s   SCA        SCA Types  \
#                                                        SCA  SCA90  PassLive
# league             season team
# ENG-Premier League 2021   Arsenal           29  38.0   817  21.50       621
#                           Aston Villa       24  38.0   935  24.61       655
#                           Brighton          27  38.0   843  22.18       617
#                           Burnley           25  38.0   671  17.66       467
#                           Chelsea           27  38.0  1022  26.89       782
#                           Crystal Palace    24  38.0   621  16.34       428
#                           Everton           29  38.0   718  18.89       512
#                           Fulham            28  38.0   786  20.68       568
#                           Leeds United      23  38.0   930  24.47       692
#                           Leicester City    27  38.0   861  22.66       625
# ...

# %%
possession_stats.to_csv("possession.csv",sep=",")
