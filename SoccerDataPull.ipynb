# %%
import soccerdata as sd
# Out:
# [11/04/22 10:15:30] INFO     No custom team name replacements found. You can configure these in       ]8;id=823368;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=352316;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py#85\85]8;;\
#                              /Users/animeshsengupta/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=443123;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=762313;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_config.py#155\155]8;;\
#                              /Users/animeshsengupta/soccerdata/config/league_dict.json.

# %%
seasons=[x for x in range(16,22)]
seasons
# Out:
# [16, 17, 18, 19, 20, 21]

# %%
five38 = sd.FiveThirtyEight('ENG-Premier League', seasons)
# Out:
# [11/04/22 12:48:10] INFO     Saving cached data to                                                    ]8;id=904401;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=407656;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#89\89]8;;\
#                              /Users/animeshsengupta/soccerdata/data/FiveThirtyEight

# %%
games = five38.read_games()

print(games.columns)
# Out:
# Index(['date', 'status', 'leg', 'home_team', 'away_team', 'home_id', 'away_id',
#        'home_code', 'away_code', 'prob_home', 'prob_away', 'prob_tie', 'round',
#        'spi1', 'spi2', 'quality', 'leverage', 'score_home', 'score_away',
#        'adj_score_home', 'adj_score_away', 'chances_home', 'chances_away',
#        'moves_home', 'moves_away', 'aggregate_winner', 'shootout_winner',
#        'matchday'],
#       dtype='object')

# %%
games.head(10)
# Out:
#                                                                                               date  \
# league             season game
# ENG-Premier League 1617   2016-08-13 Burnley-Swansea City                2016-08-13 14:00:00+00:00
#                           2016-08-13 Crystal Palace-West Bromwich Albion 2016-08-13 14:00:00+00:00
#                           2016-08-13 Everton-Tottenham Hotspur           2016-08-13 14:00:00+00:00
#                           2016-08-13 Hull City-Leicester City            2016-08-13 11:30:00+00:00
#                           2016-08-13 Manchester City-Sunderland          2016-08-13 16:30:00+00:00
#                           2016-08-13 Middlesbrough-Stoke City            2016-08-13 14:00:00+00:00
#                           2016-08-13 Southampton-Watford                 2016-08-13 14:00:00+00:00
#                           2016-08-14 AFC Bournemouth-Manchester United   2016-08-14 12:30:00+00:00
# ...

# %%
fbref = sd.FBref(leagues="Big 5 European Leagues Combined",seasons=seasons, no_cache=True, no_store=True)
# Out:
# [11/04/22 12:48:22] INFO     Caching is disabled                                                      ]8;id=739566;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=302503;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#87\87]8;;\

# %%
output=[]
for i in seasons:
    fbref = sd.FBref(leagues="Big 5 European Leagues Combined",seasons=i, no_cache=True, no_store=True)
    output.append(fbref)
# Out:
# [11/04/22 12:52:37] INFO     Caching is disabled                                                      ]8;id=604460;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=637527;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#87\87]8;;\
#                     INFO     Caching is disabled                                                      ]8;id=833006;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=143692;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#87\87]8;;\
#                     INFO     Caching is disabled                                                      ]8;id=552347;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=165141;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#87\87]8;;\
# ...

# %%
season_stats = output[1].read_team_season_stats(stat_type='shooting')

# %%
season_stats.head(20)
# Out:
#                                           # Pl   90s Standard                  \
#                                                           Gls   Sh  SoT  SoT%
# league             season team
# ENG-Premier League 1718   Arsenal           30  38.0       73  589  223  37.9
#                           Bournemouth       22  38.0       45  462  153  33.1
#                           Brighton          24  38.0       33  377  110  29.2
#                           Burnley           24  38.0       35  378  126  33.3
#                           Chelsea           26  38.0       60  603  210  34.8
#                           Crystal Palace    28  38.0       44  466  134  28.8
#                           Everton           30  38.0       42  351  110  31.3
#                           Huddersfield      25  38.0       25  360  106  29.4
#                           Leicester City    27  38.0       53  417  137  32.9
#                           Liverpool         27  38.0       82  635  226  35.6
# ...

# %%
goalshot_stats = output[1].read_team_season_stats(stat_type='goal_shot_creation')
# Out:
# [11/04/22 13:00:59] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=961761;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=532762;file:///opt/homebrew/lib/python3.10/site-packages/soccerdata/_common.py#342\342]8;;\
#                              1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-pack
#                              ages/urllib3/connectionpool.py", line 703, in urlopen
#                                  httplib_response = self._make_request(
#                                File
#                              "/opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-pack
#                              ages/urllib3/connectionpool.py", line 449, in _make_request
#                                  six.raise_from(e, None)
# ...

# %%
possession_stats.head(30)
# Out:
#                                           # Pl   90s   SCA        SCA Types  \
#                                                        SCA  SCA90  PassLive
# league             season team
# ENG-Premier League 2021   Arsenal           29  38.0   817  21.50       621
#                           Aston Villa       24  38.0   935  24.61       655
#                           Brighton          27  38.0   843  22.18       617
#                           Burnley           25  38.0   671  17.66       467
#                           Chelsea           27  38.0  1022  26.89       782
#                           Crystal Palace    24  38.0   621  16.34       428
#                           Everton           29  38.0   718  18.89       512
#                           Fulham            28  38.0   786  20.68       568
#                           Leeds United      23  38.0   930  24.47       692
#                           Leicester City    27  38.0   861  22.66       625
# ...

# %%
possession_stats.to_csv("Sample_data/possession.csv",sep=",")

# %%
season_stats.to_csv("Sample_data/season_stats.csv",sep=",")

# %%
games.to_csv("Sample_data/games.csv",sep=",")
